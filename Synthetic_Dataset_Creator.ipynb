# %% [markdown]
# from random import randint
# import pandas as pd
#
# fake = Faker()
#
# def input_data(x):
#
#     # pandas dataframe
#     data = pd.DataFrame()
#     for i in range(0, x):
#         data.loc[i,'id']= randint(1, 100)
#         data.loc[i,'name']= fake.name()
#         data.loc[i,'address']= fake.address()
#         data.loc[i,'latitude']= str(fake.latitude())
#         data.loc[i,'longitude']= str(fake.longitude())
#     return data
#
#
# input_data(10)

# %%
from random import randint

# %%
import pandas as pd

# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-35.2.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.11/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from Faker) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.4->Faker) (1.17.0)
# Downloading Faker-35.2.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.3 MB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-35.2.0

# %%
from faker import Faker
fake = Faker()

# %%
print(fake.name())
# Out:
# Alyssa Martin

# %%
fake_name = fake.name()
fake_address = fake.address()
fake_text = fake.text()
fake_number = fake.random_number(digits=5)
fake_date = fake.date_of_birth(minimum_age=18, maximum_age=90)
fake_email = fake.email()
fake_phone_number = fake.phone_number()
fake_company = fake.company()
fake_credit_card_number = fake.credit_card_number()
fake_color = fake.color_name()
fake_user_agent = fake.user_agent()
fake_uuid = fake.uuid4()
fake_file_path = fake.file_path()
fake_image_url = fake.image_url()
fake_profile_picture = fake.image_url(width=200, height=200)

# %%
print("Fake Name:", fake_name)
print("Fake Address:", fake_address)
print("Fake Text:", fake_text)
print("Fake Number:", fake_number)
print("Fake Date:", fake_date)
print("Fake Email:", fake_email)
print("Fake Phone Number:", fake_phone_number)
print("Fake Company:", fake_company)
print("Fake Credit Card Number:", fake_credit_card_number)
print("Fake Color:", fake_color)
print("Fake User Agent:", fake_user_agent)
print("Fake UUID:", fake_uuid)
print("Fake File Path:", fake_file_path)
print("Fake Image URL:", fake_image_url)
print("Fake Profile Picture:", fake_profile_picture)
# Out:
# Fake Name: Jessica Coleman
# Fake Address: 5208 Hammond Mission Suite 679
# New Belinda, CA 82189
# Fake Text: Address to hope picture. Feel public leave concern only forget pressure boy.
# Live employee claim both. Describe serve test final.
# Fake Number: 64630
# Fake Date: 1999-12-29
# Fake Email: tcalhoun@example.net
# Fake Phone Number: (796)231-6705x3305
# Fake Company: Smith, Harvey and Carr
# Fake Credit Card Number: 2720234169294824
# Fake Color: RoyalBlue
# Fake User Agent: Mozilla/5.0 (Android 10; Mobile; rv:35.0) Gecko/35.0 Firefox/35.0
# Fake UUID: 9bf9e2ac-f2ac-45b9-830b-fa8c50506d3e
# Fake File Path: /score/tough.xls
# Fake Image URL: https://placekitten.com/455/352
# Fake Profile Picture: https://placekitten.com/200/200

# %%
from faker import Faker
import pandas as pd
from random import randint

fake = Faker()

def input_data(x):
    # pandas dataframe
    data = pd.DataFrame()
    for i in range(0, x):
        data.loc[i,'id'] = randint(1, 100)
        #data.loc[i, 'prefix_male'] = str(fake.prefix_male())
        data.loc[i, 'suffix_female'] = str(fake.suffix_female())

        data.loc[i,'name'] = fake.name()
        data.loc[i,'address'] = fake.address()
        #data.loc[i,'latitude'] = str(fake.latitude())
        #data.loc[i,'longitude'] = str(fake.longitude())
        data.loc[i,'company'] = str(fake.company())

        data.loc[i,'number'] = str(randint(1000000000, 9000000000))  # Convert phone number to string

    return data

input_data(10)
# Out:
#      id suffix_female                      name  \
# 0  92.0            MD          Ashley Rodriguez
# 1  75.0            MD             Phillip Nunez
# 2  26.0           DDS            Barry Williams
# 3  64.0           PhD          Michael Mcdonald
# 4  74.0           DDS              Ronald Black
# 5  32.0           DDS            Katelyn Mendez
# 6  14.0            MD  Mr. Nicholas Brennan PhD
# 7   6.0           PhD              Robin Murphy
# 8  28.0           DDS              Edward Baker
# 9  42.0           DVM            Anita Caldwell
#
#                                              address  \
# 0    99942 Deborah Village\nElizabethhaven, ND 21955
# 1       08251 David Island\nPort Danielton, LA 38826
# 2       05281 Kramer Plaza\nEast Lauraberg, VT 02838
# 3          8031 Billy Lock\nWest Gailville, TN 14442
# 4  56058 Johnson Terrace Apt. 229\nSouth Johnberg...
# 5      684 Delgado Parkway\nSouth Adrienne, AZ 82062
# 6       36812 Robert Groves\nEast Kathleen, AZ 36875
# 7   8396 Matthew Islands\nWest Melissaland, SC 60210
# 8    606 Wells Villages\nSouth Matthewside, MH 63225
# 9                       USNV Henderson\nFPO AE 63009
#
#                         company      number
# 0                     Perry LLC  3481610404
# 1             Townsend-Gonzalez  4827272302
# 2                   Lopez-Myers  8615460149
# 3                 Johnson Group  4204482635
# 4     Smith, Ramirez and Chavez  1174410366
# 5                     Ewing Ltd  4820596284
# 6               Thomas and Sons  3663028129
# 7                   Marsh-Sharp  2826521123
# 8                   Ellis-Booth  3842556617
# 9  Johnson, Lawrence and Osborn  6587529865

# %%
from faker import Faker

fake = Faker()

# List all attributes and methods of the Faker object
print(dir(fake))
# Out:
# ['__annotations__', '__class__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_factories', '_factory_map', '_locales', '_map_provider_method', '_optional_proxy', '_select_factory', '_select_factory_choice', '_select_factory_distribution', '_unique_proxy', '_weights', 'aba', 'add_provider', 'address', 'administrative_unit', 'am_pm', 'android_platform_token', 'ascii_company_email', 'ascii_email', 'ascii_free_email', 'ascii_safe_email', 'bank_country', 'basic_phone_number', 'bban', 'binary', 'boolean', 'bothify', 'bs', 'building_number', 'cache_pattern', 'catch_phrase', 'century', 'chrome', 'city', 'city_prefix', 'city_suffix', 'color', 'color_hsl', 'color_hsv', 'color_name', 'color_rgb', 'color_rgb_float', 'company', 'company_email', 'company_suffix', 'coordinate', 'country', 'country_calling_code', 'country_code', 'credit_card_expire', 'credit_card_full', 'credit_card_number', 'credit_card_provider', 'credit_card_security_code', 'cryptocurrency', 'cryptocurrency_code', 'cryptocurrency_name', 'csv', 'currency', 'currency_code', 'currency_name', 'currency_symbol', 'current_country', 'current_country_code', 'date', 'date_between', 'date_between_dates', 'date_object', 'date_of_birth', 'date_this_century', 'date_this_decade', 'date_this_month', 'date_this_year', 'date_time', 'date_time_ad', 'date_time_between', 'date_time_between_dates', 'date_time_this_century', 'date_time_this_decade', 'date_time_this_month', 'date_time_this_year', 'day_of_month', 'day_of_week', 'del_arguments', 'dga', 'domain_name', 'domain_word', 'dsv', 'ean', 'ean13', 'ean8', 'ein', 'email', 'emoji', 'enum', 'factories', 'file_extension', 'file_name', 'file_path', 'firefox', 'first_name', 'first_name_female', 'first_name_male', 'first_name_nonbinary', 'fixed_width', 'format', 'free_email', 'free_email_domain', 'future_date', 'future_datetime', 'generator_attrs', 'get_arguments', 'get_formatter', 'get_providers', 'get_words_list', 'hex_color', 'hexify', 'hostname', 'http_method', 'http_status_code', 'iana_id', 'iban', 'image', 'image_url', 'internet_explorer', 'invalid_ssn', 'ios_platform_token', 'ipv4', 'ipv4_network_class', 'ipv4_private', 'ipv4_public', 'ipv6', 'isbn10', 'isbn13', 'iso8601', 'items', 'itin', 'job', 'job_female', 'job_male', 'json', 'json_bytes', 'language_code', 'language_name', 'last_name', 'last_name_female', 'last_name_male', 'last_name_nonbinary', 'latitude', 'latlng', 'lexify', 'license_plate', 'linux_platform_token', 'linux_processor', 'local_latlng', 'locale', 'locales', 'localized_ean', 'localized_ean13', 'localized_ean8', 'location_on_land', 'longitude', 'mac_address', 'mac_platform_token', 'mac_processor', 'md5', 'military_apo', 'military_dpo', 'military_ship', 'military_state', 'mime_type', 'month', 'month_name', 'msisdn', 'name', 'name_female', 'name_male', 'name_nonbinary', 'nic_handle', 'nic_handles', 'null_boolean', 'numerify', 'opera', 'optional', 'paragraph', 'paragraphs', 'parse', 'passport_dates', 'passport_dob', 'passport_full', 'passport_gender', 'passport_number', 'passport_owner', 'password', 'past_date', 'past_datetime', 'phone_number', 'port_number', 'postalcode', 'postalcode_in_state', 'postalcode_plus4', 'postcode', 'postcode_in_state', 'prefix', 'prefix_female', 'prefix_male', 'prefix_nonbinary', 'pricetag', 'profile', 'provider', 'providers', 'psv', 'pybool', 'pydecimal', 'pydict', 'pyfloat', 'pyint', 'pyiterable', 'pylist', 'pyobject', 'pyset', 'pystr', 'pystr_format', 'pystruct', 'pytimezone', 'pytuple', 'random', 'random_choices', 'random_digit', 'random_digit_above_two', 'random_digit_not_null', 'random_digit_not_null_or_empty', 'random_digit_or_empty', 'random_elemen ...
